# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D

import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-1db82c0a51cf> in <module>
#       5 import time
#       6 from numba import njit
# ----> 7 from pyccel.epyccel import epyccel
#       8 from pyccel.decorators import types
#
# ~\anaconda3\lib\site-packages\pyccel\epyccel.py in <module>
#      17 from importlib.machinery import ExtensionFileLoader
#      18
# ---> 19 from pyccel.codegen.pipeline import execute_pyccel
#      20 from pyccel.errors.errors import ErrorsMode
#      21
#
# ~\anaconda3\lib\site-packages\pyccel\codegen\pipeline.py in <module>
#      24
#      25 from .compiling.basic     import CompileObj
# ---> 26 from .compiling.compilers import Compiler
#      27
#      28 pyccel_stage = PyccelStage()
#
# ~\anaconda3\lib\site-packages\pyccel\codegen\compiling\compilers.py in <module>
#      15 import warnings
#      16 from filelock import FileLock
# ---> 17 from pyccel.compilers.default_compilers import available_compilers, vendors
#      18 from pyccel.errors.errors import Errors
#      19
#
# ~\anaconda3\lib\site-packages\pyccel\compilers\default_compilers.py in <module>
#      33     gfort_info['mpi']['flags']    = ('-D','USE_MPI_MODULE')
#      34     gfort_info['mpi']['libs']     = ('msmpi',)
# ---> 35     gfort_info['mpi']['includes'] = (os.environ["MSMPI_INC"].rstrip('\\'),)
#      36     gfort_info['mpi']['libdirs']  = (os.environ["MSMPI_LIB64"].rstrip('\\'),)
#      37
#
# ~\anaconda3\lib\os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: 'MSMPI_INC'

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu):
    row, col = u.shape
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    
    for n in range(nt):
        for i in range(row):
            for j in range(col):
                un[i , j]=u[i , j]
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i , j]= un[ i , j] - nu * dt / (dx**2) * (un[i+1 , j] - 2* un[i,j] + un[i-1 , j]) - nu * dt / (dy**2) * (un[i , j+1] - 2 * un[i,j] + un[i , j-1])                
              
        
        
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit(fastmath=True)
def solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu):
    row, col = u.shape
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    for n in range(nt):
        for i in range(row):
            for j in range(col):
                un[i , j]=u[i , j]
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i , j]= un[ i , j] - nu * dt / (dx**2) * (un[i+1 , j] - 2* un[i,j] + un[i-1 , j]) - nu * dt / (dy**2) * (un[i , j+1] - 2 * un[i,j] + un[i , j-1])                
              
        
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
def solve_2d_diff_pyccel(u:'float[:]', un:'float[:]', nt:'int', dt:'float', dx:'float', dy:'float', nu:'float'):
    row, col = u.shape
    
    ##Assign initial conditions
    #set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    for n in range(nt):
        for i in range(row):
            for j in range(col):
                un[i , j]=u[i , j]
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i , j]= un[ i , j] - nu * dt / (dx**2) * (un[i+1 , j] - 2* un[i,j] + un[i-1 , j]) - nu * dt / (dy**2) * (un[i , j+1] - 2 * un[i,j] + un[i , j-1])                
        
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nt = 51
nx = 101
ny = 101
nu = .05
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx))  # create a 1xn vector of 1's
un = np.ones((ny, nx))
    

solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu)

fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')                      
X, Y = np.meshgrid(x, y)                            
surf = ax.plot_surface(X, Y, u, cmap=cm.viridis)

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_diff_pure(u, un, nt, dt, dx, dy, nu)
# Out:
# 5.52 s ± 241 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_diff_numba(u, un, nt, dt, dx, dy, nu)
# Out:
# 2.31 ms ± 840 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-800e2c6ed56b> in <module>
# ----> 1 solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)
#
# NameError: name 'epyccel' is not defined

# %%
# %timeit solve_2d_diff_f90(u, un, nt, dt, dx, dy, nu)

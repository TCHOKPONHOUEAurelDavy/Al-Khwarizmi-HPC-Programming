# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D

import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-1db82c0a51cf> in <module>
#       5 import time
#       6 from numba import njit
# ----> 7 from pyccel.epyccel import epyccel
#       8 from pyccel.decorators import types
#
# ~\anaconda3\lib\site-packages\pyccel\epyccel.py in <module>
#      17 from importlib.machinery import ExtensionFileLoader
#      18
# ---> 19 from pyccel.codegen.pipeline import execute_pyccel
#      20 from pyccel.errors.errors import ErrorsMode
#      21
#
# ~\anaconda3\lib\site-packages\pyccel\codegen\pipeline.py in <module>
#      24
#      25 from .compiling.basic     import CompileObj
# ---> 26 from .compiling.compilers import Compiler
#      27
#      28 pyccel_stage = PyccelStage()
#
# ~\anaconda3\lib\site-packages\pyccel\codegen\compiling\compilers.py in <module>
#      15 import warnings
#      16 from filelock import FileLock
# ---> 17 from pyccel.compilers.default_compilers import available_compilers, vendors
#      18 from pyccel.errors.errors import Errors
#      19
#
# ~\anaconda3\lib\site-packages\pyccel\compilers\default_compilers.py in <module>
#      33     gfort_info['mpi']['flags']    = ('-D','USE_MPI_MODULE')
#      34     gfort_info['mpi']['libs']     = ('msmpi',)
# ---> 35     gfort_info['mpi']['includes'] = (os.environ["MSMPI_INC"].rstrip('\\'),)
#      36     gfort_info['mpi']['libdirs']  = (os.environ["MSMPI_LIB64"].rstrip('\\'),)
#      37
#
# ~\anaconda3\lib\os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: 'MSMPI_INC'

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_poisson_pure(p, pd, b, nx, ny, nt, dx, dy):
    
    row, col = p.shape
    # Source
    b[int(ny / 4), int(nx / 4)]  = 100
    b[int(3 * ny / 4), int(3 * nx / 4)] = -100
    
    
    for it in range(nt):
        for i in range(nx): pd[i] = p[i]
        for j in range(2, row):
            for i in range(2, col):
                p[j-1, i-1] = (((pd[j-1, i] + pd[j-1, i-2]) * dy**2 +
                                (pd[j, i-1] + pd[j-2, i-1]) * dx**2 -
                                b[j-1, i-1] * dx**2 * dy**2) / 
                                (2 * (dx**2 + dy**2)))
        p[0, :] = 0
        p[ny-1, :] = 0
        p[:, 0] = 0
        p[:, nx-1] = 0
        
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit(fastmath=True)
def solve_2d_poisson_numba(p, pd, b, nx, ny, nt, dx, dy):
    
    row, col = p.shape
    # Source
    b[int(ny / 4), int(nx / 4)]  = 100
    b[int(3 * ny / 4), int(3 * nx / 4)] = -100
    
    
    for it in range(nt):
        for i in range(nx): pd[i] = p[i]
        for j in range(2, row):
            for i in range(2, col):
                p[j-1, i-1] = (((pd[j-1, i] + pd[j-1, i-2]) * dy**2 +
                                (pd[j, i-1] + pd[j-2, i-1]) * dx**2 -
                                b[j-1, i-1] * dx**2 * dy**2) / 
                                (2 * (dx**2 + dy**2)))
        p[0, :] = 0
        p[ny-1, :] = 0
        p[:, 0] = 0
        p[:, nx-1] = 0
        
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
@types('float[:,:]', 'float[:,:]','float[:,:]', 'int', 'int', 'int','float', 'float')
def solve_2d_poisson_pyccel(p, pd, b, nx, ny, nt, dx, dy):
    
    row, col = p.shape
    # Source
    b[int(ny / 4), int(nx / 4)]  = 100
    b[int(3 * ny / 4), int(3 * nx / 4)] = -100
    
    
    for it in range(nt):
        for i in range(nx): pd[i] = p[i]
        for j in range(2, row):
            for i in range(2, col):
                p[j-1, i-1] = (((pd[j-1, i] + pd[j-1, i-2]) * dy**2 +
                                (pd[j, i-1] + pd[j-2, i-1]) * dx**2 -
                                b[j-1, i-1] * dx**2 * dy**2) / 
                                (2 * (dx**2 + dy**2)))
        p[0, :] = 0
        p[ny-1, :] = 0
        p[:, 0] = 0
        p[:, nx-1] = 0
        
    return 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6c0a2a088121> in <module>
# ----> 1 @types('float[:,:]', 'float[:,:]','float[:,:]', 'int', 'int', 'int','float', 'float')
#       2 def solve_2d_poisson_pyccel(p, pd, b, nx, ny, nt, dx, dy):
#       3
#       4     row, col = p.shape
#       5     # Source
#
# NameError: name 'types' is not defined

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nx = 50
ny = 50
nt  = 100
xmin = 0
xmax = 2
ymin = 0
ymax = 1

dx = (xmax - xmin) / (nx - 1)
dy = (ymax - ymin) / (ny - 1)

# Initialization
p  = np.zeros((ny, nx))
pd = np.zeros((ny, nx))
b  = np.zeros((ny, nx))
x  = np.linspace(xmin, xmax, nx)
y  = np.linspace(xmin, xmax, ny)

solve_2d_poisson_pure(p, pd, b, nx, ny, nt, dx, dy)

fig = pyplot.figure(figsize=(10, 7), dpi=100)
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, p, rstride=1, cstride=1, cmap=cm.viridis, linewidth=0, antialiased=False)
ax.view_init(30, 225)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0.5, 0, '$y$')

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_poisson_pure(p, pd, b, nx, ny, nt, dx, dy)
# Out:
# 468 ms ± 6.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_poisson_numba(p, pd, b, nx, ny, nt, dx, dy)
# Out:
# 1.59 ms ± 145 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_poisson_f90 = epyccel(solve_2d_poisson_pyccel)

# %%
# %timeit solve_2d_poisson_f90(p, pd, b, nx, ny, nt, dx, dy)
# Out:
# 374 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

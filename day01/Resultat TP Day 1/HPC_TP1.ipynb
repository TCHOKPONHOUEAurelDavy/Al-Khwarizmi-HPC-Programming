# %% [markdown]
# > #### $\textbf{Bandwidth et CPU TIME dans le cas des Stride}$

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# > ### $\textbf{-OO}$

# %%
OO = [1 , 0.000000, 2.357000, 3236.909008, 
2 , 0.000000, 2.625000, 2906.436012,
3 , 0.000000, 2.733000, 2791.582339,
4 , 0.000000, 2.918000, 2614.597166,
5 , 0.000000, 3.383000, 2255.215646,
6 , 0.000000, 3.545000, 2152.156426,
7 , 0.000000, 4.048000, 1884.731851,
8 , 0.000000, 4.446000, 1716.013165,
9 , 0.000000, 5.170000, 1475.704938, 
10 , 0.000000, 5.249000, 1453.494862, 
11 , 0.000000, 5.918000, 1289.184612, 
12 , 0.000000, 7.446000, 1024.629940, 
13 , 0.000000, 6.494000, 1174.837470, 
14 , 0.000000, 7.259000, 1051.025559, 
15 , 0.000000, 7.979000, 956.184300, 
16 , 0.000000, 9.015000, 846.300003, 
17 , 0.000000, 8.030000, 950.111399, 
18 , 0.000000, 9.074000, 840.797281, 
19 , 0.000000, 8.475000, 900.223544, 
20 , 0.000000, 8.508000, 896.731844 
]

# %% [markdown]
# > ### $\textbf{-O2}$

# %%
O2 = [1 , 0.000000, 1.294000, 5895.977227, 
2 , 0.000000, 1.388000, 5496.681939, 
3 , 0.000000, 1.490000, 5120.399014, 
4 , 0.000000, 1.871000, 4077.709530, 
5 , 0.000000, 2.289000, 3333.068821, 
6 , 0.000000, 3.257000, 2342.460710, 
7 , 0.000000, 3.858000, 1977.551719, 
8 , 0.000000, 3.726000, 2047.609912, 
9 , 0.000000, 4.123000, 1850.447376, 
10 , 0.000000, 4.667000, 1634.753489, 
11 , 0.000000, 5.113000, 1492.156177, 
12 , 0.000000, 5.827000, 1309.317750, 
13 , 0.000000, 6.790000, 1123.622170, 
14 , 0.000000, 7.168000, 1064.368657, 
15 , 0.000000, 7.327000, 1041.271261, 
16 , 0.000000, 9.264000, 823.552950, 
17 , 0.000000, 10.602000, 719.618424, 
18 , 0.000000, 11.579000, 658.899260, 
19 , 0.000000, 13.924000, 547.931236, 
20 , 0.000000, 14.644000, 520.991159,
]

# %%
plt.figure(figsize=(11, 8))
plt.plot([i for i in range(1, 21)], O2[2:len(O2):4], '-o', label='CPU Time(msec) -O2')
plt.plot([i for i in range(1, 21)], OO[2:len(OO):4], '-o', label='CPU Time(msec) -O0')
plt.xlabel("Stride", fontsize=14)
plt.ylabel(" CPU Time(msec)", fontsize=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot([i for i in range(1, 21)], O2[3:len(O2):4], '-o', label='BANDWIDTH (MB/s) -O2')
plt.plot([i for i in range(1, 21)], OO[3:len(OO):4], '-o', label='BANDWIDTH (MB/s) -OO')

plt.xlabel("Stride", fontsize=14)
plt.ylabel("BANDWIDTH(MB/s)", fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
#  #### $\textbf{Bandwidth et CPU TIME dans le cas du produit block par block de deux matrices}$

# %%
MB=[2,819.514000, 37238.629389, 
5,543.968000, 56101.789306,
10,377.019000, 80944.403664, 
20,460.163000, 66319.061126, 
40,676.469000, 45113.047494, 
]

# %%
plt.figure(figsize=(10, 8))
plt.plot(MB[0:len(MB):3],MB[1:len(MB):3], '-o', label='CPU Time(msec) -O2')
plt.xlabel("Block Size", fontsize=14)
plt.ylabel(" CPU Time(msec)", fontsize=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(MB[0:len(MB):3],MB[2:len(MB):3], '-o', label='BANDWIDTH (MB/s) -O2')

plt.xlabel("Block Size", fontsize=14)
plt.ylabel("BANDWIDTH(MB/s)", fontsize=14)
plt.legend()
plt.show()

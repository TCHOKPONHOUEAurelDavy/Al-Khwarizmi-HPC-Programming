# %% [markdown]
# *Note: all those exercises should be done using python with pyccel openmp*

# %% [markdown]
# ## Exercise 1 Hello World
#
# 1. Write an OpenMP program displaying the number of threads used for the execution and the rank of each of the threads.
# 3. Test the programs obtained with different numbers of threads for the parallel program.
#
# **Output Example**
# ```shell
# >> Python hello.py
# Hello from the rank 2 thread
# Hello from the rank 0 thread
# Hello from the rank 3 thread
# Hello from the rank 1 thread
# Hello from the rank 4 thread
# Parallel execution of hello_world with 4 threads
# ```
# *Note that the output order maybe different*

# %%
import pyccel

# %%
# %%file hello.py
 # write your program here
if __name__=="__main__":
    from pyccel.stdlib.internal.openmp import omp_get_thread_num, omp_get_num_threads, omp_set_num_threads
    omp_set_num_threads(3)
    #$ omp parallel
    rank=omp_get_thread_num()
    print("Hello from the rank",rank,"thread")
    result=omp_get_num_threads()
    #$ omp end parallel
    print("Parallel execution of hello_world with",result,"threads")
# Out:
# Overwriting hello.py

# %%
# !pyccel --language=c hello.py --openmp
# !./hello
# Out:
# Hello from the rank 0 thread
# Hello from the rank 2 thread
# Hello from the rank 1 thread
# Parallel execution of hello_world with 3 threads

# %%
if __name__=="__main__":
    sum = 0
    #$ omp parallel num_threads(4) private(i) shared(sum)
    #$ omp for
    for i in range(0, 1337):
      #$ omp critical
      sum += i
      #$ omp end critical
    #$ omp end parallel
    print(sum)
# Out:
# 893116

# %% [markdown]
# ## Exercise 2 Matrix product
#
# Considering the following code for matrix product:
#
# 1. Using pyccel, epyccelize the `matrix_prod` function, and time the execution of epyccelized function.
# 2. Insert the appropriate OpenMP directives and analyse the code performance.
# 3. Test the loop iteration repartition modes (`STATIC`, `DYNAMIC`, `GUIDED`) and vary the chunk sizes.
# **Example output**
#
# ```bash
#    Value of M and N           : 20 20
#     Temps elapsed              : 0.0009012222290039062
#     Temps CPU                  : 0.0
#     Partiel results            : 2790.0 2690.0 ... -3610.0 -4350.0
#
#  Execution of Matrix production in parallele with                     8 threads
# ```

# %%
from pyccel.decorators import types

# %%
@types('float[:,:]','float[:,:]','float[:,:]','int','int')
def matrix_prod(A, B, C, N, M):


    #$ omp parallel private (i,j) 
    #$ omp for collapse(2)
    for i in range( M ):
        for j in range( N ):
            A[ i, j ] = (i + 1) + (j + 1)
    

    #$ omp for collapse(2)  
    for i in range( N ):
        for j in range( M ):
            B[ i, j ] = (i + 1) - (j + 1)

    #$ omp for collapse(2)   
    for i in range( M ):
        for j in range( M ):
            C[ i, j ] = 0
  

    #$ omp barrier
    #$ omp for    
    for i in range( M ):
        for j in range( M ):
            for k in range( N ):
                C[ i, j ] += A[ i, k ] * B[ k, j ]

    #$ omp end parallel
    return 0


    

if __name__ == "__main__":
    from pyccel.stdlib.internal.openmp import omp_set_num_threads,omp_get_num_threads
    omp_set_num_threads(4)
    
    # Pycelyse le produit de matrix 
    from pyccel.epyccel import epyccel
    p_prodmat = epyccel(matrix_prod, language='c', accelerators=['openmp'])
    
    import numpy as np
    import time
    import math
    
    M = 20
    N = 20

    # Declare Matrices
    A = np.empty((M, N), dtype=np.double)
    B = np.empty((N, M), dtype=np.double)
    C = np.empty((M, M), dtype=np.double)
    
    # start CPU timing
    cpu_0 = time.process_time()

    # start Wall timing
    elapsed_0 = time.time()

    # run and time the matrix_prod function  
    p_prodmat(A,B,C,N,M)
    
    result= omp_get_num_threads()
    # CPU time
    cpu_1 = time.process_time()
    cpu = cpu_1 - cpu_0

    # Wall timing
    elapsed_1 = time.time()
    elapsed = elapsed_1 - elapsed_0


    print(
        "Value of M and N    :", M,  N,        '\n',
        "Elapsed Time   :", elapsed,    '\n',
        "CPU time       :", cpu,        '\n',
        #"Execution of Matrix production in parallele with",result, "threads"
    )
# Out:
# Value of M and N    : 20 20
#  Elapsed Time   : 0.0013017654418945312
#  CPU time       : 0.002011627000000127

# %% [markdown]
# ## Exercise 3 Jacobi method
#
# Considering the following code for a general linear system solver:
#
# $$ A \times x = b $$
#
# using the Jacobi iterative method.
# In this exercice, you must solve the system in parallel
#
# **Example Output**
#
# ```bash
# System size    : 20
#  Iterations     : 21
#  Stand          : 2.9100049961372497e-08
#  Elapsed Time   : 7.447303771972656
#  CPU time       : 0.921875
# ```

# %%
@types('float[:,:]','float[:]','float[:]','int','float')
def jacobi(a, b, x, n, eps):

#     print("Execution of Jacobi in parallel with", nb_tasks, "threads")
    # Jacobi method resolution
    import numpy as np
    import math
    x_courant = np.empty(n, dtype=np.double)
    iteration = 0
    #$ omp parallel
    while(1):
        iteration += 1
        
        #$ omp for
        for i in range(n):
            x_courant[i] = 0.
            for j in range(i):
                x_courant[i] += a[ j, i ] * x[j]

            for j in range(i + 1, n):
                x_courant[i] += a[ j, i ] * x[j]

            x_courant[i] = (b[i] - x_courant[i]) / a[ i, i ]
        
        # Convergence test
        absmax = 0.
        #omp for
        for i in range(n):
            curr = math.fabs(x[i] - x_courant[i])
            if curr > absmax:
                absmax = curr
        stand = absmax / n
        if stand <= eps or iteration > n:
            
            break

        # copy x_courant into 
        #omp for
        for i in range(n):
            x [i] = x_courant[i]
        
    #$ omp end parallel
        
    return stand, iteration

# %%
if __name__ == "__main__":
    from pyccel.stdlib.internal.openmp import omp_set_num_threads,omp_get_num_threads
    omp_set_num_threads(4)
    
    import numpy as np
    import time, random, math, sys

    # Matrix default dimension
    n = 20
    diag = 20

    # Initialize of the matrices
    np.random.seed(421)  # for reproductibles results
    a = np.random.uniform(0, 1, size=(n, n))
    b = np.random.uniform(0, 1, size=n)

    # We strengthen the main diagonal of the matrix
    for i in range(n):
        a[ i, i ] += diag

    # Initial solution
    x = np.ones(n, dtype=np.double)

    # start CPU timing
    cpu_0 = time.process_time()

    # start Wall timing
    elapsed_0 = time.time()

    # Pyccelize jacobi function
    from pyccel.epyccel import epyccel
    p_jacobi = epyccel(jacobi, language='fortran',accelerators=['openmp'])

    eps = sys.float_info.epsilon
    
    # -------------------- computing ------------------
    stand, iteration = p_jacobi(a, b, x, n, eps)
    # ------------------ End computing ----------------

    # CPU time
    cpu_1 = time.process_time()
    cpu = cpu_1 - cpu_0

    # Wall timing
    elapsed_1 = time.time()
    elapsed = elapsed_1 - elapsed_0

    print(
        "System size    :", n,          '\n',
        "Iterations     :", iteration,  '\n',
        "Stand          :", stand,      '\n',
        "Elapsed Time   :", elapsed,    '\n',
        "CPU time       :", cpu,        '\n'
    )
# Out:
# ERROR at Fortran compilation stage
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_14139/3510149403.py in <module>
#      30     # Pyccelize jacobi function
#      31     from pyccel.epyccel import epyccel
# ---> 32     p_jacobi = epyccel(jacobi, language='fortran',accelerators=['openmp'])
#      33
#      34     eps = sys.float_info.epsilon
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/epyccel.py in epyccel(python_function_or_module, **kwargs)
#     331     # Serial version
#     332     else:
# --> 333         mod, fun = epyccel_seq( python_function_or_module, **kwargs )
#     334
#     335     # Return Fortran function (if any), otherwise module
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/epyccel.py in epyccel_seq(function_or_module, language, compiler, fflags, wrapper_flags, accelerators, verbose, debug, includes, libdirs, modules, libs, folder)
#     166         try:
#     167             # Generate shared library
# --> 168             execute_pyccel(pymod_filename,
#     169                            verbose       = verbose,
#     170                            language      = language,
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/codegen/pipeline.py in execute_pyccel(fname, syntax_only, semantic_only, convert_only, verbose, folder, language, compiler, fflags, wrapper_flags, includes, libdirs, modules, libs, debug, accelerators, output_name, compiler_export_file)
#     362     # Compile code to modules
#     363     try:
# --> 364         src_compiler.compile_module(compile_obj=mod_obj,
#     365                 output_folder=pyccel_dirpath,
#     366                 verbose=verbose)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/codegen/compiling/compilers.py in compile_module(self, compile_obj, output_folder, verbose)
#     274             compile_obj.acquire_lock()
#     275         try:
# --> 276             self.run_command(cmd, verbose)
#     277         finally:
#     278             compile_obj.release_lock()
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/codegen/compiling/compilers.py in run_command(cmd, verbose)
#     397             err_msg = "Failed to build module"
#     398             err_msg += "\n" + err
# --> 399             raise RuntimeError(err_msg)
#     400         if err:
#     401             warnings.warn(UserWarning(err))
#
# RuntimeError: Failed to build module
# /home/aurel/Documents/Al-Khwarizmi-HPC-Programming/day03/assignments/__epyccel__/__pyccel__/mod_1wy6xr3i2vl5_1wy6xr3i2vl5.f90:58:14:
#
#    58 |         !$omp cancel
#       |              1
# Error: Unclassifiable OpenMP directive at (1)

# %% [markdown]
# ## Exercise 4 Calculation of π
#
# The aim of this exercise is to calculate π by numerical integration knowing that Considering the following code for matrix product: $\int_{0}^{1} \frac{4}{1 + x^2} = {\pi} $
#
# The following program is for calculating the value of
# π by the rectangle method (mid-point). Let $f(x) = \frac{4}{1 + x^2} $
# 2 be the function to integrate, N and $ h = \frac{1}{N} $ (respectively) the number of points, and the discretization width on the integration
# interval $[0, 1]$.
#
# Analyse the performance of the codes, then optimise  your code using OpenMP directives.

# %%
# %%file pi.py

def f(a:'float'):
    return  4.0 / (1. + a * a)


def pi(n:'int', h:'float'):
    #print("Execution of PI in parallel with", nb_tasks,"threads")
    #$ omp parallel
    #$ omp for
    for k in range(100):
        Pi_calc = 0.
        for i in range(n):
            x = h * (i + 0.5)
            Pi_calc = Pi_calc +f(x)

        Pi_calc = h * Pi_calc
    #$ omp end parallel
    return Pi_calc

# %%
if __name__ == '__main__':
    from pyccel.stdlib.internal.openmp import omp_get_thread_num, omp_get_num_threads, omp_set_num_threads
    omp_set_num_threads(3)
    
    import time, math
    #                  __
    #  But : calcul de || par la methode des rectangles (point milieu).
    #
    #                   / 1
    #                  |       4            __
    #                  |   ----------  dx = ||
    #                  |    1 + x**2
    #                 / 0


    n = 300

    # Length of the integration interval
    h = 1.0 / n

    from pyccel.epyccel import epyccel
    import pi
    pyc_pi = epyccel(pi, language='fortran',accelerators=['openmp'])

    # start timing
    tcpu_0 = time.process_time() # CPU time
    t_elapsed_0 = time.time()    # Wall time

    # -------------------- computing ------------------

    Pi_calc = pyc_pi.pi(n, h)

    # ------------------ End computing ----------------

    # CPU time spent
    tcpu_1 = time.process_time()
    tcpu = tcpu_1 - tcpu_0

    # Wall time spent
    t_elapsed_1 = time.time()
    t_elapsed = t_elapsed_1 - t_elapsed_0

    # deviation between the estimated value and the calculated value of Pi
    Pi_estime = math.acos(-1)
    deviat = math.fabs(Pi_estime - Pi_calc)

    # Print result
    print(
      "   Number of intervals        :", n,         "\n",
	  "   | Pi_estime - Pi_calcule | :", deviat,    "\n",
	  "   Temps elapsed              :", t_elapsed, "\n",
	  "   Temps CPU                  :", tcpu,      "\n",
    )

# %% [markdown]
# ## Exercise 5 Reduction of an array
#
# The given program contained in the `reduction_tab.py` file is extracted from a chemistry code. It reduces a three-dimensional array into a vector. The aim of this exercise is to parallelize this calculation kernel without changing the loop order in the provided code (i.e. k,j,i)
#
# 1. Analyse the data-sharing attributes of the variables and adapt the source code so that the K outermost loop is parallelized.
# 2. Compare the performance obtained by using the thread/core binding default execution on Ada and by using scatter binding. Suggest an explanation for the poor performance of the latter.
# 3. Optimise the source code for the scatter mode with taking into account the memory affinity. Why does this third series of executions give the best performance

# %%
# %%file reduction_tab.py

@types('float[:,:,:]','int','int','int')
def initialize_table(tab, nmolec, n, nmol):
    # Initialisation du tableau
    # First-touch pour garantir un fonctionnement optimal sur les systemes NUMA
    #$ omp parallel
    #$ omp for
    for k in range(nmolec):
        for j in range(n):
            for i in range(nmol):
                tab[ i,j,k ] = i + j + k
    #$ omp end parallel
    

@types('float[:,:,:]','float[:]','float[:]','int','int','int')
def reduction(tab, tab1, tab2, nmolec, nmol, n):
    #$ omp parallel
    #$ omp for
    for k in range(nmolec):
        tab1[:nmol] = 0
        for j in range(n):
            for i in range(nmol):
                tab1[i] = tab1[i] + tab[i,j,k]
        tab2[:nmol] = tab2[:nmol] + 2 * tab1[:nmol]
    
    #$ omp end parallel

# %%
from os import error

if __name__ == '__main__':
    from pyccel.stdlib.internal.openmp import omp_get_thread_num, omp_get_num_threads, omp_set_num_threads
    omp_set_num_threads(3)
    
    import numpy as np
    import time

    # default dimension
    nmolec = 100
    nmol   = 100
    n      = 10

    tab     = np.empty((nmol, n, nmolec), dtype=np.double)
    tab1    = np.empty((nmol), dtype=np.double)
    tab2    = np.zeros((nmol), dtype=np.double)

    # pyccelize reduction tab module
    from pyccel.epyccel import epyccel
    import reduction_tab
    
    reduction = epyccel(reduction_tab, language='fortran', accelerators=['openmp'])
    
#     print("Execution of reduction table in parallele with", reduction.threads_num, "threads")

    # initialize tab 
    reduction.initialize_table(tab, nmol, n, nmolec)

    # start timing
    tcpu_0 = time.process_time() # CPU time
    t_elapsed_0 = time.time()    # Wall time

    # -------------------- computing ------------------
    reduction.reduction(tab, tab1, tab2, nmolec, nmol, n)
    # ------------------ End computing ----------------

    # CPU time spent
    tcpu_1 = time.process_time()
    tcpu = tcpu_1 - tcpu_0

    # Wall time spent
    t_elapsed_1 = time.time()
    t_elapsed = t_elapsed_1 - t_elapsed_0

    # verification of results
    tab2c = np.zeros((nmol), dtype=np.double)
    for k in range(nmolec):
        tab1c = np.zeros((nmol), dtype=np.double)
        for j in range(n):
            for i in range(nmol):
                tab1c[i] = tab1c[i] + tab[i, j, k]
        tab2c [:] = tab2c[:nmol] + 2 * tab1c[:]
    err = np.max(np.abs(tab2c - tab2) / np.abs(tab2c))
    print(
        "Temps elapsed  :", t_elapsed   , "\n",
        "Temps CPU      :", tcpu        , "\n",
        "Erreur relative:", err         , "\n"
    )

# %% [markdown]
# # Exercise 6 Matrix product by the Strassen algorithm
#
# Considering the following code that calculates the matrix product :
#
# $$C = A \times B$$
#
# by using Strassen’s recursive algorithm.
#
# In this exercise, you must :
# 1. Analyse and parallelize the code by using OpenMP tasks.
# 2. Measure the code performance and plot the speedup curves obtained.

# %%
import time, math
import numpy as np

def strassen_multiply(A:'foat[:,:]', B:'float[:,:]', C:'float[:,:]', n:'int'):
    A11 float[:]
    import numpy as np
    #$ omp parallel
    if n & 1 != 0  or n < 128:
        #$ omp section
        C[:] = np.matmul(A, B)
        #$ omp end section
    else:
        n2 = n // 2
        
        #$ omp sections nowait
        #$ omp section
        A11 = A[ 0:n2, 0:n2 ]
        A21 = A[ n2:n, 0:n2 ]
        A12 = A[ 0:n2, n2:n ]
        A22 = A[ n2:n, n2:n ]
        #$ omp end section
        #$ omp section
        B11 = B[ 0:n2, 0:n2 ]
        B21 = B[ n2:n, 0:n2 ]
        B12 = B[ 0:n2, n2:n ]
        B22 = B[ n2:n, n2:n ]
        #$ omp end section
        
        #$ omp section
        Q1 = np.empty((n2, n2), dtype=np.double)
        Q2 = np.empty((n2, n2), dtype=np.double)
        Q3 = np.empty((n2, n2), dtype=np.double)
        Q4 = np.empty((n2, n2), dtype=np.double)
        Q5 = np.empty((n2, n2), dtype=np.double)
        Q6 = np.empty((n2, n2), dtype=np.double)
        Q7 = np.empty((n2, n2), dtype=np.double)
        #$ omp end section
        #$ omp end sections
        
        #$ omp sections nowait
        #$ omp section
        strassen_multiply(A11+A22, B11+B22, Q1, n2)
        #$ omp end section
        #$ omp section
        strassen_multiply(A21+A22, B11, Q2, n2)
        #$ omp end section
        #$ omp section
        strassen_multiply(A11, B12-B22, Q3, n2)
        #$ omp end section
        #$ omp section
        strassen_multiply(A22, -B11+B21, Q4, n2) 
        #$ omp end section
        #$ omp section
        strassen_multiply(A11+A12, B22, Q5, n2)
        #$ omp end section
        #$ omp section
        strassen_multiply(-A11+A21, B11+B12, Q6, n2)
        #$ omp end section
        #$ omp section
        strassen_multiply(A12-A22, B21+B22, Q7, n2)
        #$ omp end section
        #$ omp end sections
        
        #$ omp sections nowait
        #$ omp section
        C[   :n2,   :n2 ] = Q1+Q4-Q5+Q7
        #$ omp end section
        #$ omp section
        C[ n2: n,   :n2 ] = Q2+Q4
        #$ omp end section
        #$ omp section
        C[   :n2, n2:n  ] = Q3+Q5
        #$ omp end section
        #$ omp section
        C[ n2:n , n2:n  ] = Q1+Q3-Q2+Q6
        #$ omp end section
        #$ omp end sections
        
    #omp end parallel


def calcul_erreur(n:'int',A:'foat[:,:]', B:'float[:,:]', C:'float[:,:]'):
    D = np.matmul(A, B) 
    error = 0.0
    #$ omp parallel
    #$ omp for
    for i in range(n):
        for j in range(n):
            e = C[ i, j ] - D[ i, j ]
            error += e * e

    error = math.sqrt(error) / n
    #$ omp end parallel
    return error

if __name__ == '__main__':
    from pyccel.stdlib.internal.openmp import omp_get_thread_num, omp_get_num_threads, omp_set_num_threads
    omp_set_num_threads(3)
    
    n = 256

    # Initialize Matrices
    np.random.seed(421)
    A = np.random.uniform(0, 1, (n, n))
    B = np.random.uniform(0, 1, (n, n))
    C = np.empty((n,n), dtype=np.double)

    from pyccel.epyccel import epyccel
    strassen = epyccel(strassen_multiply, accelerators=['openmp'])
    num_threads = epyccel(threads_num, accelerators=['openmp'])
    print("Execution of Strassen in parallele with", num_threads(), "threads")
    
    
    # Start timing
    tcpu_0 = time.process_time() # CPU time
    t_elapsed_0 = time.time()    # Wall time
    # -------------------- computing ------------------
    # Calcul C=A*B par la methode recursive de Strassen
    strassen(A, B, C, n)
    # ------------------ end computing ----------------
    # CPU time spent
    tcpu_1 = time.process_time()
    tcpu = tcpu_1 - tcpu_0

    # Wall time spent
    t_elapsed_1 = time.time()
    t_elapsed = t_elapsed_1 - t_elapsed_0
    # Print result
    print(
      "   Erreur        :", calcul_erreur(n, A, B, C),  "\n",
	  "   Temps elapsed :", t_elapsed,                  "\n",
	  "   Temps CPU     :", tcpu,                       "\n",
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14139/2035205864.py in <module>
#     106
#     107     from pyccel.epyccel import epyccel
# --> 108     strassen = epyccel(strassen_multiply, accelerators=['openmp'])
#     109     num_threads = epyccel(threads_num, accelerators=['openmp'])
#     110     print("Execution of Strassen in parallele with", num_threads(), "threads")
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/epyccel.py in epyccel(python_function_or_module, **kwargs)
#     331     # Serial version
#     332     else:
# --> 333         mod, fun = epyccel_seq( python_function_or_module, **kwargs )
#     334
#     335     # Return Fortran function (if any), otherwise module
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/epyccel.py in epyccel_seq(function_or_module, language, compiler, fflags, wrapper_flags, accelerators, verbose, debug, includes, libdirs, modules, libs, folder)
#     166         try:
#     167             # Generate shared library
# --> 168             execute_pyccel(pymod_filename,
#     169                            verbose       = verbose,
#     170                            language      = language,
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/codegen/pipeline.py in execute_pyccel(fname, syntax_only, semantic_only, convert_only, verbose, folder, language, compiler, fflags, wrapper_flags, includes, libdirs, modules, libs, debug, accelerators, output_name, compiler_export_file)
#     232     try:
#     233         settings = {'verbose':verbose}
# --> 234         parser.annotate(**settings)
#     235     except NotImplementedError as error:
#     236         msg = str(error)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/parser.py in annotate(self, **settings)
#     161
#     162         # Create a new semantic parser and store it in object
# --> 163         parser = SemanticParser(self._syntax_parser,
#     164                                 d_parsers=self.d_parsers,
#     165                                 parents=self.parents,
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in __init__(self, inputs, **kwargs)
#     198         # ... TOD add settings
#     199         settings = {}
# --> 200         self.annotate()
#     201         # ...
#     202
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in annotate(self, **settings)
#     246         # we add the try/except to allow the parser to find all possible errors
#     247         pyccel_stage.set_stage('semantic')
# --> 248         ast = self._visit(ast, **settings)
#     249
#     250         self._ast = ast
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_Module(self, expr, **settings)
#    1425
#    1426     def _visit_Module(self, expr, **settings):
# -> 1427         body = self._visit(expr.program).body
#    1428         program_body      = []
#    1429         init_func_body    = []
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_CodeBlock(self, expr, **settings)
#    1590
#    1591             # Save parsed code
# -> 1592             line = self._visit(b, **settings)
#    1593             ls.extend(self._additional_exprs[-1])
#    1594             self._additional_exprs[-1] = []
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_FunctionDef(self, expr, **settings)
#    3035
#    3036             # we annotate the body
# -> 3037             body = self._visit(expr.body)
#    3038
#    3039             # Calling the Garbage collecting,
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_CodeBlock(self, expr, **settings)
#    1590
#    1591             # Save parsed code
# -> 1592             line = self._visit(b, **settings)
#    1593             ls.extend(self._additional_exprs[-1])
#    1594             self._additional_exprs[-1] = []
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_If(self, expr, **settings)
#    2740
#    2741     def _visit_If(self, expr, **settings):
# -> 2742         args = [self._visit(i, **settings) for i in expr.blocks]
#    2743
#    2744         conds = [b.condition for b in args]
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in <listcomp>(.0)
#    2740
#    2741     def _visit_If(self, expr, **settings):
# -> 2742         args = [self._visit(i, **settings) for i in expr.blocks]
#    2743
#    2744         conds = [b.condition for b in args]
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_IfSection(self, expr, **settings)
#    2729         else:
#    2730             cond = self._visit(expr.condition)
# -> 2731         body = self._visit(expr.body)
#    2732         if prog_check:
#    2733             # Calling the Garbage collecting,
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_CodeBlock(self, expr, **settings)
#    1590
#    1591             # Save parsed code
# -> 1592             line = self._visit(b, **settings)
#    1593             ls.extend(self._additional_exprs[-1])
#    1594             self._additional_exprs[-1] = []
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_Assign(self, expr, **settings)
#    2069             macro = self.namespace.find(name, 'macros')
#    2070             if macro is None:
# -> 2071                 rhs = self._visit(rhs, **settings)
#    2072             elif isinstance(lhs, PyccelSymbol) and lhs.is_temp:
#    2073                 return self._visit(rhs, **settings)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_FunctionCall(self, expr, **settings)
#    1969         func     = self.namespace.find(name, 'functions')
#    1970
# -> 1971         args = self._handle_function_args(expr.args, **settings)
#    1972
#    1973         if name == 'lambdify':
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _handle_function_args(self, arguments, **settings)
#     760         args  = []
#     761         for arg in arguments:
# --> 762             a = self._visit(arg, **settings)
#     763             if isinstance(a.value, StarredArguments):
#     764                 args.extend([FunctionCallArgument(av) for av in a.value.args_var])
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_FunctionCallArgument(self, expr, **settings)
#    1574
#    1575     def _visit_FunctionCallArgument(self, expr, **settings):
# -> 1576         value = self._visit(expr.value, **settings)
#    1577         return FunctionCallArgument(value, expr.keyword)
#    1578
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit(self, expr, **settings)
#    1413             annotation_method = '_visit_' + cls.__name__
#    1414             if hasattr(self, annotation_method):
# -> 1415                 obj = getattr(self, annotation_method)(expr, **settings)
#    1416                 if isinstance(obj, Basic) and self._current_fst_node:
#    1417                     obj.set_fst(self._current_fst_node)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _visit_PyccelAdd(self, expr, **settings)
#    1923                 expr_new = PythonTuple(*tuple_args)
#    1924         else:
# -> 1925             expr_new = self._create_PyccelOperator(expr, args)
#    1926         return expr_new
#    1927
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/parser/semantic.py in _create_PyccelOperator(self, expr, visited_args)
#     721         """
#     722         try:
# --> 723             expr_new = type(expr)(*visited_args)
#     724         except PyccelSemanticError as err:
#     725             msg = str(err)
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/ast/operators.py in __init__(self, arg1, arg2, simplify)
#     362
#     363     def __init__(self, arg1, arg2, simplify = False):
# --> 364         super().__init__(arg1, arg2)
#     365
#     366     @classmethod
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/ast/operators.py in __init__(self, *args)
#     125             super().__init__()
#     126             return
# --> 127         self._set_dtype()
#     128         self._set_shape_rank()
#     129         # rank is None for lambda functions
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/ast/operators.py in _set_dtype(self)
#     132
#     133     def _set_dtype(self):
# --> 134         self._dtype, self._precision = self._calculate_dtype(*self._args)  # pylint: disable=no-member
#     135
#     136     def _set_shape_rank(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pyccel/ast/operators.py in _calculate_dtype(cls, *args)
#     390             return cls._handle_integer_type(integers)
#     391         else:
# --> 392             raise TypeError('cannot determine the type of {}'.format(args))
#     393
#     394     @staticmethod
#
# TypeError: cannot determine the type of (Variable('A11', dtype=Pyccelfoat()), Variable('A22', dtype=Pyccelfoat()))
